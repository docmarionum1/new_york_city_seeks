# %%
import pandas as pd

# %%
jobs_df.columns
# Out:
# Index(['Job ID', 'Agency', 'Posting Type', '# Of Positions', 'Business Title',
#        'Civil Service Title', 'Title Code No', 'Level', 'Job Category',
#        'Full-Time/Part-Time indicator', 'Salary Range From', 'Salary Range To',
#        'Salary Frequency', 'Work Location', 'Division/Work Unit',
#        'Job Description', 'Minimum Qual Requirements', 'Preferred Skills',
#        'Additional Information', 'To Apply', 'Hours/Shift', 'Work Location 1',
#        'Recruitment Contact', 'Residency Requirement', 'Posting Date',
#        'Post Until', 'Posting Updated', 'Process Date'],
#       dtype='object')

# %%
jobs_df = pd.read_csv('jobs.csv')
jobs_df
# Out:
#       Job ID                          Agency Posting Type  # Of Positions  \
# 0      86699     DEPT OF CITYWIDE ADMIN SVCS     External               2
# 1      86699     DEPT OF CITYWIDE ADMIN SVCS     External               2
# 2      87990    DEPARTMENT OF BUSINESS SERV.     Internal               1
# 3      97899    DEPARTMENT OF BUSINESS SERV.     Internal               1
# 4     102221  DEPT OF ENVIRONMENT PROTECTION     External               1
# 5     102221  DEPT OF ENVIRONMENT PROTECTION     Internal               1
# 6     114352  DEPT OF ENVIRONMENT PROTECTION     Internal               5
# 7     117261  DEPT OF ENVIRONMENT PROTECTION     External               1
# 8     133921           NYC HOUSING AUTHORITY     Internal              50
# 9     117261  DEPT OF ENVIRONMENT PROTECTION     Internal               1
# 10    120749  DEPT OF ENVIRONMENT PROTECTION     Internal               1
# 11    120749  DEPT OF ENVIRONMENT PROTECTION     External               1
# ...

# %%
jobs_df2 = pd.read_csv('jobs2.csv', encoding='utf-8')
#jobs_df2
jobs_df2['Minimum Qual Requirements'].iloc[1]
# Out:
# '(1) A baccalaureate degree, with a major in fine or graphic arts, from an accredited college and one year of full-time paid experience as a commercial or graphic artist; or    (2) A four-year high school diploma or its educational equivalent plus two years of training in a technical school approved by a stateâ€™s Department of Education or comparable governmental agency, in oils, water colors, painting, design, black and white, layout, computer graphics, and other art media, and three years of acceptable full-time paid experience as a commercial or graphic artist.    To be qualified for assignment to Assignment Level II, individuals must have:  (a) at least one year of experience as a Graphic Artist, Assignment Level I; or  (b) the Qualification Requirements described in "1" or "2" above, plus two additional years of acceptable specialized paid experience conceptualizing and initiating graphic art projects.'

# %%
jobs_df2['Minimum Qual Requirements'].iloc[1].encode('windows-1252').decode('utf-8')
# Out:
# '(1) A baccalaureate degree, with a major in fine or graphic arts, from an accredited college and one year of full-time paid experience as a commercial or graphic artist; or    (2) A four-year high school diploma or its educational equivalent plus two years of training in a technical school approved by a state’s Department of Education or comparable governmental agency, in oils, water colors, painting, design, black and white, layout, computer graphics, and other art media, and three years of acceptable full-time paid experience as a commercial or graphic artist.    To be qualified for assignment to Assignment Level II, individuals must have:  (a) at least one year of experience as a Graphic Artist, Assignment Level I; or  (b) the Qualification Requirements described in "1" or "2" above, plus two additional years of acceptable specialized paid experience conceptualizing and initiating graphic art projects.'

# %%
cols = ['Job ID', 'Agency', 'Business Title',
       'Civil Service Title',
       'Job Description', 'Preferred Skills']

new_df = pd.concat([jobs_df, jobs_df2]).reset_index(drop=True).drop_duplicates(subset=cols)[cols]

new_df
# Out:
#       Job ID                          Agency  \
# 0      86699     DEPT OF CITYWIDE ADMIN SVCS
# 2      87990    DEPARTMENT OF BUSINESS SERV.
# 3      97899    DEPARTMENT OF BUSINESS SERV.
# 4     102221  DEPT OF ENVIRONMENT PROTECTION
# 6     114352  DEPT OF ENVIRONMENT PROTECTION
# 7     117261  DEPT OF ENVIRONMENT PROTECTION
# 8     133921           NYC HOUSING AUTHORITY
# 10    120749  DEPT OF ENVIRONMENT PROTECTION
# 12    121583                  LAW DEPARTMENT
# 14    124287                  LAW DEPARTMENT
# 16    124564  DEPT OF ENVIRONMENT PROTECTION
# 18    311990  MAYORS OFFICE OF CONTRACT SVCS
# 19    124839  DEPT OF ENVIRONMENT PROTECTION
# 21    128877  DEPT OF ENVIRONMENT PROTECTION
# 23    132292           NYC HOUSING AUTHORITY
# 25    132786  DEPT OF ENVIRONMENT PROTECTION
# 27    228889   DEPT OF HEALTH/MENTAL HYGIENE
# 29    134511  DEPT OF ENVIRONMENT PROTECTION
# 30    134515  DEPT OF ENVIRONMENT PROTECTION
# 31    137433   DEPT OF HEALTH/MENTAL HYGIENE
# ...

# %%
new_df.to_csv('jobs_clean.csv', index=False, encoding='utf-8')

# %%
c = pd.concat([jobs_df, jobs_df2])

# %%
c
# Out:
#       Job ID                          Agency Posting Type  # Of Positions  \
# 0      86699     DEPT OF CITYWIDE ADMIN SVCS     External               2
# 1      86699     DEPT OF CITYWIDE ADMIN SVCS     External               2
# 2      87990    DEPARTMENT OF BUSINESS SERV.     Internal               1
# 3      97899    DEPARTMENT OF BUSINESS SERV.     Internal               1
# 4     102221  DEPT OF ENVIRONMENT PROTECTION     External               1
# 5     102221  DEPT OF ENVIRONMENT PROTECTION     Internal               1
# 6     114352  DEPT OF ENVIRONMENT PROTECTION     Internal               5
# 7     117261  DEPT OF ENVIRONMENT PROTECTION     External               1
# 8     133921           NYC HOUSING AUTHORITY     Internal              50
# 9     117261  DEPT OF ENVIRONMENT PROTECTION     Internal               1
# 10    120749  DEPT OF ENVIRONMENT PROTECTION     Internal               1
# 11    120749  DEPT OF ENVIRONMENT PROTECTION     External               1
# ...

# %%
c.groupby('Job ID').count()
# Out:
#         Agency  Posting Type  # Of Positions  Business Title  \
# Job ID
# 86699        4             4               4               4
# 87990        2             2               2               2
# 97899        2             2               2               2
# 102221       4             4               4               4
# 114352       2             2               2               2
# 117261       4             4               4               4
# 120749       4             4               4               4
# 121583       4             4               4               4
# 124287       4             4               4               4
# 124564       4             4               4               4
# 124839       4             4               4               4
# 128877       4             4               4               4
# 132292       4             4               4               4
# 132786       4             4               4               4
# ...

# %%
q = c[c['Job ID'] == 86699][cols]
q
# Out:
#    Job ID                       Agency Posting Type  Business Title  \
# 0   86699  DEPT OF CITYWIDE ADMIN SVCS     External  Graphic Artist
# 1   86699  DEPT OF CITYWIDE ADMIN SVCS     External  Graphic Artist
# 0   86699  DEPT OF CITYWIDE ADMIN SVCS     External  Graphic Artist
# 1   86699  DEPT OF CITYWIDE ADMIN SVCS     External  Graphic Artist
#
#   Civil Service Title Title Code No Level Salary Frequency  \
# 0      GRAPHIC ARTIST         91415     1           Annual
# 1      GRAPHIC ARTIST         91415     1           Annual
# 0      GRAPHIC ARTIST         91415     1           Annual
# 1      GRAPHIC ARTIST         91415     1           Annual
#
#         Work Location Division/Work Unit  \
# 0  1 Centre St., N.Y.      City Graphics
# 1  1 Centre St., N.Y.      City Graphics
# 0  1 Centre St., N.Y.      City Graphics
# 1  1 Centre St., N.Y.      City Graphics
#
#                                      Job Description  \
# 0  Under the direct supervision, with some latitu...
# ...

# %%
q['Minimum Qual Requirements'].iloc[0] == q['Minimum Qual Requirements'].iloc[3]
# Out:
# False

# %%
q['Minimum Qual Requirements'].iloc[0]
# Out:
# '(1) A baccalaureate degree, with a major in fine or graphic arts, from an accredited college and one year of full-time paid experience as a commercial or graphic artist; or    (2) A four-year high school diploma or its educational equivalent plus two years of training in a technical school approved by a state’s Department of Education or comparable governmental agency, in oils, water colors, painting, design, black and white, layout, computer graphics, and other art media, and three years of acceptable full-time paid experience as a commercial or graphic artist.    To be qualified for assignment to Assignment Level II, individuals must have:  (a) at least one year of experience as a Graphic Artist, Assignment Level I; or  (b) the Qualification Requirements described in "1" or "2" above, plus two additional years of acceptable specialized paid experience conceptualizing and initiating graphic art projects.'

# %%
q['Preferred Skills'].iloc[3]
# Out:
# '2D animation skills are required but 3D animation optional.  Proficient with Adobe CS4 and CS5 software specifically illustrator, Photoshop, indesign, acrobat and flash.  Proficient with MAC and P.C.'
